# %%
import pandas as pd
import numpy as np

# %%
def no_dupes(df):
    
    #creating df of number of times a claim repeats

    repeats = df['ClaimID'].value_counts().to_frame().reset_index()

    #getting list of duplicate claims
    
    all_dupes = repeats[repeats['ClaimID']>1]
    dupes = all_dupes['index'].to_list()
   

    #getting one index value per duplicate claim

    goodi=[]
    for e in dupes:
        goodi.append(min(df[df['ClaimID'].isin([e])].index.to_list()))
    
    # full list of duplicate claim indicies

    alli=[]
    for e in dupes:
        alli = alli + df[df['ClaimID'].isin([e])].index.to_list()


    # take goodi from alli
    badi = [i for i in alli if i not in goodi]

    #drop duplicate indicies
    return(df.drop(index=badi).reset_index())

# %%
column_list = ['TotalFirstYearGrosskWh',
       'TotalFirstYearGrossTherm','TotalLifecycleGrosskWh',
       'TotalLifecycleGrossTherm','Budget']
def aggregate_me(df, by, lg, column_list):
    
    # making df usable

    df[by] = df[by].str.upper()
    
    #filtering for local government

    if lg: 

        lglist = ['Local Government (Counties)',
         'Local Government ()',
         'Local Government (Cities)',
         'Local Government ']

        df = df[df['Grouping'].isin(lglist)]


    # creating a total programs column

    prg = df.groupby([by, 'PrgID'], dropna = False).size().index.tolist() 
    #need to count the number of times a city/county shows up 

    e,f = [list(c) for c in zip(*prg)]

    ccp = pd.Series(e) # made a series so can use value_counts

    ccp = ccp.str.upper()

    tp = ccp.value_counts(dropna = False) #total programs per city
    
    # creating a total claims column
    
    df['total_claims'] = [1]*len(df)
    
    #aggregate!
    relevant_columns = column_list + ['total_claims']
    agg = df.groupby(by).sum()[relevant_columns]
    agg['total_programs'] = tp
    
    # Resource/OBF budget as percentage of total budget
    obf_budget = df.groupby([by, 'OBF_Flag']).Budget.sum().unstack().fillna(0).loc[:, True]
    resource_budget = df.groupby([by, 'Resource_Flag']).Budget.sum().unstack().fillna(0).loc[:, 1]
    agg['perc_obf_budget'] = (obf_budget/agg['Budget'])*100
    agg['perc_resource_budget'] = (resource_budget/agg['Budget'])*100
    
    return(agg.reset_index())

# %% [markdown]
# ## Testing functions

# %%
cpuc = pd.read_csv('data/cpuc_with_budget_and_resource.csv')
# Out:
# C:\Users\audre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7,12,17,19,22,23,24,27,47,48,56,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# get rid of Unnamed: 0 column because otherwise wayyyy too many duplicates for my no_dupes function to work without taking forever

# %%
copy = cpuc.copy()

copy.drop(columns='Unnamed: 0', inplace=True)

copy.drop_duplicates(inplace=True)

# %%
copy.shape
# Out:
# (599974, 72)

# %% [markdown]
# ### no_dupes test

# %%
# %%time

no_dupes(copy)
# Out:
# Wall time: 1.75 s

# %%
yay = no_dupes(copy)

# %%
yay['ClaimID'].value_counts()
# Out:
# SCE-2018-Q4-0113270                  1
# SCG-2019-3711-12120676-3197087       1
# SCE-2018-Q4-0101559                  1
# PGE-2017-Q4-63376                    1
# PGE-2018-Q4-75109                    1
#                                     ..
# SDGE-2019-3245-10977194-12234198S    1
# SCG-2019-3805-12118934-3193552       1
# SDGE-2019-3245-10981321-12259530     1
# PGE-2018-Q4-88349                    1
# SCE-2017-Q4-0199765                  1
# Name: ClaimID, Length: 599968, dtype: int64

# %%
copy.shape
# Out:
# (599974, 72)

# %%
copy['ClaimID'].value_counts()
# Out:
# SCE-2018-Q2-0069119                 2
# SCE-2018-Q4-0101513                 2
# SCE-2017-Q4-0201431                 2
# SCE-2018-Q4-0114147                 2
# SCE-2017-Q4-0201694                 2
#                                    ..
# SCG-2019-3805-12118934-3193552      1
# SDGE-2019-3245-10981321-12259530    1
# PGE-2018-Q4-88349                   1
# SDGE-2019-3224-11003707-12465587    1
# SCE-2017-Q4-0199765                 1
# Name: ClaimID, Length: 599968, dtype: int64

# %% [markdown]
# ### aggregate_me test

# %%
aggregate_me(yay, 'SiteCity', True, ['Budget', 'TotalFirstYearGrosskWh'])
# Out:
# <ipython-input-130-54fe90ed6554>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Claims'] = [1]*len(df)
#                                Budget  TotalFirstYearGrosskWh  Total Claims  \
# SiteCity
# ACAMPO                   17684.568509            48664.726740             6
# ADELANTO                 27320.063231            13576.844232             4
# ALAMO                    48785.542683            73049.392600            15
# ALBANY                   60926.193528           153765.922000            35
# ALHAMBRA                 48465.447601            21630.949392             7
# ...                               ...                     ...           ...
# WOODLAND                278715.826268           526910.057920           358
# YORBA LINDA             230594.633505           100589.028000            12
# YOSEMITE NATIONAL PARK   18234.382541             8894.000000             4
# YOUNTVILLE                4901.835174            16598.672480            57
# YUBA CITY               637530.085904           898299.606760           450
#
#                         Total Programs
# SiteCity
# ACAMPO                               1
# ADELANTO                             1
# ALAMO                                1
# ALBANY                               2
# ALHAMBRA                             1
# ...                                ...
# WOODLAND                             2
# YORBA LINDA                          1
# YOSEMITE NATIONAL PARK               1
# YOUNTVILLE                           2
# YUBA CITY                            3
#
# [537 rows x 4 columns]

# %%
yay[yay['SiteCity']=='ACAMPO'].PrgID.value_counts()
# Out:
# PGE21012     9
# PGE211030    6
# Name: PrgID, dtype: int64

# %%
yay.columns
# Out:
# Index(['ClaimID', 'PrgID', 'Sector_x', 'SiteCity', 'SiteZipCode', 'SiteID',
#        'NAICSCode', 'BldgHVAC', 'BldgLoc', 'BldgType', 'BldgVint',
#        'E3ClimateZone', 'E3GasSavProfile', 'E3GasSector',
#        'E3MeaElecEndUseShape', 'E3TargetSector', 'ImplementationID',
#        'InstallationDate', 'NAICSBldgType', 'NumUnits', 'OBF_Flag',
#        'PrgElement', 'RateScheduleElec', 'RateScheduleGas', 'REN_Flag',
#        'Residential_Flag', 'SchoolIdentifier', 'TotalFirstYearGrosskW',
#        'TotalFirstYearGrosskWh', 'TotalFirstYearGrossTherm',
#        'TotalGrossIncentive', 'TotalGrossMeasureCost',
#        'TotalGrossMeasureCost_ER', 'TotalLifecycleGrosskW',
#        'TotalLifecycleGrosskWh', 'TotalLifecycleGrossTherm', 'Upstream_Flag_x',
#        'WaterOnly_Flag', 'PrgYear', 'Claim ID', 'Program ID',
#        'First Year Gross kWh', 'First Year Gross Therm', 'Budget', 'PA',
#        'ProgramName', 'Grouping', 'County', 'Selected', 'PrimarySector',
#        'Sector_y', 'BP Sector', 'ProgramImplementer', 'ProgramCategory',
#        'StatewideProgram', 'ImplementationContractor', 'ProgramManager',
#        'StartYear', 'EndYear', 'Resource_Flag', 'NonResource_Flag',
#        'Deemed_Flag', 'Custom_Flag', 'Upstream_Flag_y', 'Midstream_Flag',
#        'Downstream_Flag', 'DirectInstall', 'Audit_Flag', 'Financing',
#        'ParentProgram', 'Exclude_From_Budget', 'Exclude_From_CE'],
#       dtype='object')

# %%
columns = ['Budget', 'TotalFirstYearGrosskWh', 'TotalFirstYearGrossTherm','TotalLifecycleGrosskWh', 'TotalLifecycleGrossTherm', 'OBF_Flag', 'Resource_Flag', 'Total Claims']
test = aggregate_me(yay, 'SiteCity', False, columns)
test
# Out:
#                     SiteCity        Budget  TotalFirstYearGrosskWh  \
# 0                     ACAMPO  4.031116e+04            5.135173e+04
# 1                      ACTON  1.157423e+05            1.168743e+05
# 2                   ADELANTO  8.736705e+05            2.389739e+06
# 3                     AGOURA  7.469575e+03            2.984935e+04
# 4               AGOURA HILLS  2.134583e+05            3.737607e+05
# ...                      ...           ...                     ...
# 1021  YOSEMITE NATIONAL PARK  2.547790e+04            1.390673e+04
# 1022              YOUNTVILLE  2.665221e+04            5.969097e+04
# 1023               YUBA CITY  1.378842e+06            1.997491e+06
# 1024                 YUCAIPA  4.099928e+05            5.131031e+05
# 1025            YUCCA VALLEY  1.664178e+05            4.743738e+05
#
#       TotalFirstYearGrossTherm  TotalLifecycleGrosskWh  \
# 0                  4187.109670            6.162207e+05
# 1                   724.745606            8.603851e+05
# 2                   425.198725            1.462304e+07
# 3                  -114.149175            1.502801e+05
# 4                 23780.921320            1.908289e+06
# ...                        ...                     ...
# 1021                -36.737900            1.534581e+05
# 1022               4415.974000            5.697245e+05
# 1023              23805.462403            2.223440e+07
# 1024              37881.590152            4.685987e+06
# 1025               1488.090162            2.688795e+06
#
#       TotalLifecycleGrossTherm  OBF_Flag  Resource_Flag  Total Claims  \
# 0                 84933.316040         0             15          15.0
# 1                 10175.558937         0             62          52.0
# 2                  5461.256061         0            568         567.0
# 3                  -574.860718         0              8           8.0
# 4                305775.918080         0            115         101.0
# ...                        ...       ...            ...           ...
# 1021               -234.496500         0             11          11.0
# 1022              80364.513640         0             80          80.0
# 1023             294117.615441        52           1046        1046.0
# 1024             421490.942175         0            192         117.0
# 1025              35965.459211         0             66          50.0
#
#       Total Claims  Total Programs
# 0             15.0               2
# 1             52.0               4
# 2            567.0               7
# 3              8.0               1
# 4            101.0               7
# ...            ...             ...
# 1021          11.0               2
# 1022          80.0               3
# 1023        1046.0               8
# 1024         117.0              12
# 1025          50.0               9
#
# [1026 rows x 11 columns]

# %% [markdown]
# # **THEY WORK!!!!**
# jk don't get too excited there are still many an issue

# %% [markdown]
# want to perfect the aggregate one, ie get obf_claims and resource_claims data as percentage of budget and total programs
#
# will have parameter obf=True that will determine whether or not to go through with obf/resource claims agg, see obf_resource_budget.ipynb

# %%
test[test['Resource_Flag']>test['Total Claims']]
# Out:
#             SiteCity         Budget  TotalFirstYearGrosskWh  \
# 1              ACTON  115742.339742            1.168743e+05
# 2           ADELANTO  873670.472213            2.389739e+06
# 4       AGOURA HILLS  213458.272103            3.737607e+05
# 10          ALHAMBRA  857252.068024            1.267773e+06
# 11       ALISO VIEJO  460812.732166            1.588288e+06
# ...              ...            ...                     ...
# 1013  WOODLAND HILLS   13650.179453            3.245400e+04
# 1014    WOODLAND HLS  374392.275016           -7.173176e+02
# 1020     YORBA LINDA  831678.831350            6.762897e+05
# 1024         YUCAIPA  409992.830365            5.131031e+05
# 1025    YUCCA VALLEY  166417.772346            4.743738e+05
#
#       TotalFirstYearGrossTherm  TotalLifecycleGrosskWh  \
# 1                   724.745606            8.603851e+05
# 2                   425.198725            1.462304e+07
# 4                 23780.921320            1.908289e+06
# 10                36953.769382            1.057979e+07
# 11                25418.428892            1.211626e+07
# ...                        ...                     ...
# 1013               3486.899995            5.354910e+05
# 1014              97672.390686           -1.788276e+04
# 1020              38133.843571            4.607387e+06
# 1024              37881.590152            4.685987e+06
# 1025               1488.090162            2.688795e+06
#
#       TotalLifecycleGrossTherm  OBF_Flag  Resource_Flag  Total Claims  \
# 1                 1.017556e+04         0             62          52.0
# 2                 5.461256e+03         0            568         567.0
# 4                 3.057759e+05         0            115         101.0
# 10                5.411042e+05         0            459         433.0
# 11                3.725117e+05         0            381         220.0
# ...                        ...       ...            ...           ...
# 1013              4.273785e+04         0              8           4.0
# 1014              1.235553e+06         0            105          34.0
# 1020              4.400422e+05        12            780         691.0
# 1024              4.214909e+05         0            192         117.0
# 1025              3.596546e+04         0             66          50.0
#
#       Total Programs
# 1                  4
# 2                  7
# 4                  7
# 10                10
# 11                11
# ...              ...
# 1013               2
# 1014               5
# 1020              11
# 1024              12
# 1025               9
#
# [396 rows x 10 columns]

# %%
aggregate_me(copy, 'SiteCity', True, ['Budget', 'Resource_Flag'])
# Out:
# <ipython-input-128-c6422af5c10a>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Claims'] = [1]*len(df)
#                    SiteCity         Budget  Resource_Flag  Total Claims  \
# 0                    ACAMPO   17684.568509              6             6
# 1                  ADELANTO   27320.063231              4             4
# 2                     ALAMO   48785.542683             15            15
# 3                    ALBANY   60926.193528             35            35
# 4                  ALHAMBRA   48465.447601              7             7
# ..                      ...            ...            ...           ...
# 532                WOODLAND  278715.826268            358           358
# 533             YORBA LINDA  230594.633505             12            12
# 534  YOSEMITE NATIONAL PARK   18234.382541              4             4
# 535              YOUNTVILLE    4901.835174             57            57
# 536               YUBA CITY  637530.085904            450           450
#
#      Total Programs
# 0                 1
# 1                 1
# 2                 1
# 3                 2
# 4                 1
# ..              ...
# 532               2
# 533               1
# 534               1
# 535               2
# 536               3
#
# [537 rows x 5 columns]

# %% [markdown]
# ## something funky is going on with the total claims column, and it is not the fault of no_dupes

# %%
def aggregate_me_2(df, by, lg, column_list):
    
    # making df usable

    df[by] = df[by].str.upper()
    
    # creating a total claims column

    l = [1]*len(df)
    total_claims = pd.Series(l).rename('Total Claims from function')
    df = df.join(total_claims)
    return(df)
    #filtering for local government

    if lg: 

        lglist = ['Local Government (Counties)',
         'Local Government ()',
         'Local Government (Cities)',
         'Local Government ']

        df = df[df['Grouping'].isin(lglist)]


    # creating a total programs column

    prg = df.groupby([by, 'PrgID'], dropna = False).size().index.tolist() 
    #need to count the number of times a city/county shows up 

    e,f = [list(c) for c in zip(*prg)]

    ccp = pd.Series(e) # made a series so can use value_counts

    ccp = ccp.str.upper()

    tp = ccp.value_counts(dropna = False) #total programs per city
    
#     # creating a total claims column

#     l = [1]*len(df)
#     total_claims = pd.Series(l).rename('Total Claims from function')
#     df = df.join(total_claims)
#     return(df)
   
    #aggregate!
    relevant_columns = column_list + ['Total Claims from function']
    return(df.groupby(by).sum()[relevant_columns]
           .join(tp.rename('Total Programs'))
           .reset_index())

# %%
test2 = aggregate_me_2(copy, 'SiteCity', True, ['Budget'])

# %%
test2['Total Claims from function'].value_counts(dropna=False)
# Out:
# 1.0    123013
# NaN     69080
# Name: Total Claims from function, dtype: int64

# %%
len(test2)
# Out:
# 192093

# %%
lglist = ['Local Government (Counties)',
         'Local Government ()',
         'Local Government (Cities)',
         'Local Government ']

len(copy[copy['Grouping'].isin(lglist)])
# Out:
# 192093

# %%
test2.fillna(0)[test2.fillna(0)['Total Claims from function'] == 0 ]
# Out:
#                                             ClaimID      PrgID Sector_x  \
# 192217                            PGE-2018-Q1-17442  PGE211007      Com
# 192218                            PGE-2018-Q1-18276  PGE211009      Com
# 192219                            PGE-2018-Q1-17496  PGE211007      Com
# 192222                            PGE-2018-Q1-17494  PGE211009      Com
# 192226                            PGE-2018-Q1-18453  PGE211009      Com
# ...                                             ...        ...      ...
# 746308  SDGE-2019-3277-2019Q4PROGRAMCOSTPLACEHOLDER   SDGE3277   Public
# 746309  SDGE-2019-3278-2019Q1ProgramCostPlaceholder   SDGE3278   Public
# 746310  SDGE-2019-3278-2019Q2ProgramCostPlaceholder   SDGE3278   Public
# 746311  SDGE-2019-3278-2019Q3ProgramCostPlaceholder   SDGE3278   Public
# 746312  SDGE-2019-3278-2019Q4PROGRAMCOSTPLACEHOLDER   SDGE3278   Public
#
#           SiteCity SiteZipCode                 SiteID NAICSCode BldgHVAC  \
# 192217  EMERYVILLE       94608            PGE-1159990    922600      Any
# 192218     FREMONT       94538            PGE-1194446    921190      Any
# 192219  EMERYVILLE       94608            PGE-1159990    922600      Any
# 192222     FREMONT       94538            PGE-1148165    921190      Any
# 192226     FREMONT       94538            PGE-1148165    921190      Any
# ...            ...         ...                    ...       ...      ...
# 746308   SAN DIEGO       92123  SDGE-2019-3277-2019Q4         0      Any
# 746309   SAN DIEGO       92123  SDGE-2019-3278-2019Q1         0      Any
# 746310   SAN DIEGO       92123  SDGE-2019-3278-2019Q2         0      Any
# 746311   SAN DIEGO       92123  SDGE-2019-3278-2019Q3         0      Any
# 746312   SAN DIEGO       92123  SDGE-2019-3278-2019Q4         0      Any
#
#        BldgLoc BldgType  ... Upstream_Flag_y Midstream_Flag Downstream_Flag  \
# 192217      3A      COM  ...           False          False            True
# 192218      3B      COM  ...           False          False            True
# 192219      3A      COM  ...           False          False            True
# 192222      3B      COM  ...           False          False            True
# 192226      3B      COM  ...           False          False            True
# ...        ...      ...  ...             ...            ...             ...
# 746308    CZ07      Res  ...           False          False           False
# 746309    CZ07      Res  ...           False          False           False
# 746310    CZ07      Res  ...           False          False           False
# 746311    CZ07      Res  ...           False          False           False
# 746312    CZ07      Res  ...           False          False           False
#
#        DirectInstall Audit_Flag        Financing  \
# 192217       Partial       True             None
# 192218       Partial       True             None
# 192219       Partial       True             None
# 192222       Partial       True             None
# 192226       Partial       True             None
# ...              ...        ...              ...
# 746308            No       True  Other Financing
# 746309            No       True  Other Financing
# 746310            No       True  Other Financing
# 746311            No       True  Other Financing
# 746312            No       True  Other Financing
#
#                           ParentProgram Exclude_From_Budget Exclude_From_CE  \
# 192217  Government Partnership Programs               False           False
# 192218  Government Partnership Programs               False           False
# 192219  Government Partnership Programs               False           False
# 192222  Government Partnership Programs               False           False
# 192226  Government Partnership Programs               False           False
# ...                                 ...                 ...             ...
# 746308               Local Partnerships               False           False
# 746309               Local Partnerships               False           False
# 746310               Local Partnerships               False           False
# 746311               Local Partnerships               False           False
# 746312               Local Partnerships               False           False
#
#         Total Claims from function
# 192217                         0.0
# 192218                         0.0
# 192219                         0.0
# 192222                         0.0
# 192226                         0.0
# ...                            ...
# 746308                         0.0
# 746309                         0.0
# 746310                         0.0
# 746311                         0.0
# 746312                         0.0
#
# [69080 rows x 73 columns]

# %%
test3 = aggregate_me_2(copy, 'SiteCity', True, ['Budget', 'Resource_Flag'])

# %%
test3[test3['Resource_Flag']>test3['Total Claims from function']]
# Out:
# Empty DataFrame
# Columns: [SiteCity, Budget, Resource_Flag, Total Claims from function, Total Programs]
# Index: []

# %%
aggregate_me_2(copy, 'SiteCity', False, ['Budget', 'Resource_Flag']).fillna(0)['Total Claims from function'].value_counts()
# Out:
# 1.0    453575
# 0.0    146399
# Name: Total Claims from function, dtype: int64

# %%
l = [1]*len(copy)
total_claims = pd.Series(l).rename('Total Claims')
test4 = copy.join(total_claims)

# %%
copy.shape
# Out:
# (599974, 72)

# %%
len(copy)
# Out:
# 599974

# %%
nodups = copy.copy()

# %%
test4['Total Claims']
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 746368    NaN
# 746369    NaN
# 746370    NaN
# 746371    NaN
# 746372    NaN
# Name: Total Claims, Length: 599974, dtype: float64

# %% [markdown]
# so it looks like those nan values are left over from the og version of cpuc, the one with all of the duplicates, and for some reason those duplicate rows haven't gone away?

# %% [markdown]
# # ok now that i've got the total claims column figured out gotta figure out total programs column cuz its also incorrect
#
# actually I think it is fine because the thing i was testing on (yay) doesn't have local government programs filtered out but the ag does

# %%
ag = aggregate_me(yay, 'SiteCity', True, ['Budget'])
# Out:
# <ipython-input-3-54fe90ed6554>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total Claims'] = [1]*len(df)

# %%
len(yay[yay['SiteCity']=='ACTON']['PrgID'].value_counts())
# Out:
# 4

# %%
ag.index
# Out:
# Index(['ACAMPO', 'ADELANTO', 'ALAMO', 'ALBANY', 'ALHAMBRA', 'ALTA', 'ALTADENA',
#        'AMERICAN CANYON', 'ANAHEIM', 'ANDERSON',
#        ...
#        'WILLOW CREEK', 'WILLOWS', 'WINDSOR', 'WINTON', 'WOODACRE', 'WOODLAND',
#        'YORBA LINDA', 'YOSEMITE NATIONAL PARK', 'YOUNTVILLE', 'YUBA CITY'],
#       dtype='object', name='SiteCity', length=537)

# %% [markdown]
# ^ takes way too long cuz that for loop

# %%
yay.groupby(['SiteCity', 'PrgID']).sum().index.tolist().to_Series()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-4a3e5e4580f2> in <module>
# ----> 1 yay.groupby(['SiteCity', 'PrgID']).sum().index.tolist().to_Series()
#
# AttributeError: 'list' object has no attribute 'to_Series'

# %%
ag.iloc[372, :]
# Out:
# Budget            7081.374945
# Total Claims        13.000000
# Total Programs       1.000000
# Name: PLACENTIA, dtype: float64

# %%
agg = aggregate_me(yay, 'SiteCity', False, ['Budget'])

# %%
agg.head()
# Out:
#                      Budget  Total Claims  Total Programs
# SiteCity
# ACAMPO         40311.155034            15               2
# ACTON         115742.339742            62               4
# ADELANTO      873670.472213           568               7
# AGOURA          7469.575278             8               1
# AGOURA HILLS  213458.272103           115               7
