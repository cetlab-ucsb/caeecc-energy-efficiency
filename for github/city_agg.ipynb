# %%
import pandas as pd

# %%
cpuc = pd.read_csv('data/cpuc_with_budget_and_resource.csv')
# Out:
# C:\Users\audre\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,7,12,17,19,22,23,24,27,47,48,56,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
cpuc.columns
# Out:
# Index(['Unnamed: 0', 'ClaimID', 'PrgID', 'Sector_x', 'SiteCity', 'SiteZipCode',
#        'SiteID', 'NAICSCode', 'BldgHVAC', 'BldgLoc', 'BldgType', 'BldgVint',
#        'E3ClimateZone', 'E3GasSavProfile', 'E3GasSector',
#        'E3MeaElecEndUseShape', 'E3TargetSector', 'ImplementationID',
#        'InstallationDate', 'NAICSBldgType', 'NumUnits', 'OBF_Flag',
#        'PrgElement', 'RateScheduleElec', 'RateScheduleGas', 'REN_Flag',
#        'Residential_Flag', 'SchoolIdentifier', 'TotalFirstYearGrosskW',
#        'TotalFirstYearGrosskWh', 'TotalFirstYearGrossTherm',
#        'TotalGrossIncentive', 'TotalGrossMeasureCost',
#        'TotalGrossMeasureCost_ER', 'TotalLifecycleGrosskW',
#        'TotalLifecycleGrosskWh', 'TotalLifecycleGrossTherm', 'Upstream_Flag_x',
#        'WaterOnly_Flag', 'PrgYear', 'Claim ID', 'Program ID',
#        'First Year Gross kWh', 'First Year Gross Therm', 'Budget', 'PA',
#        'ProgramName', 'Grouping', 'County', 'Selected', 'PrimarySector',
#        'Sector_y', 'BP Sector', 'ProgramImplementer', 'ProgramCategory',
#        'StatewideProgram', 'ImplementationContractor', 'ProgramManager',
#        'StartYear', 'EndYear', 'Resource_Flag', 'NonResource_Flag',
#        'Deemed_Flag', 'Custom_Flag', 'Upstream_Flag_y', 'Midstream_Flag',
#        'Downstream_Flag', 'DirectInstall', 'Audit_Flag', 'Financing',
#        'ParentProgram', 'Exclude_From_Budget', 'Exclude_From_CE'],
#       dtype='object')

# %%
cpucbudget = pd.read_csv('data/selected_programs_merged_with_budget.csv')

# %%
df = cpucbudget[['ClaimID', 'PrgID', 'SiteCity', 'TotalFirstYearGrosskWh', 'TotalFirstYearGrossTherm','TotalLifecycleGrosskWh', 'TotalLifecycleGrossTherm', 'Budget', 'Grouping', 'Resource_Flag','OBF_Flag']]

# %%
df.shape
# Out:
# (746373, 11)

# %% [markdown]
# making total claims column

# %%
l = [1]*746373

total_claims = pd.Series(l).rename('Total Claims')

df = df.join(total_claims)

# %% [markdown]
# Total Programs column
# # THIS NEEDS TO BE OF LOCAL GOVERNMENT PROGRAMS
# updated version below

# %%
prg = df.groupby(['SiteCity', 'PrgID'], dropna = False).size().index.tolist() 
#need to count the number of times a city shows up 

a,b = [list(c) for c in zip(*prg)]

ccp = pd.Series(a) # made a series so can use value_counts

ccp = ccp.str.upper()

tp = ccp.value_counts(dropna = False) #total programs per city

print(prg[0:6])

tp.head()
# Out:
# [('ACAMPO', 'PGE21012'), ('ACAMPO', 'PGE211030'), ('ACTON', 'SCE-13-SW-002D'), ('ACTON', 'SCE-13-SW-002F'), ('ACTON', 'SCG3793'), ('ACTON', 'SCG3805')]
# LOS ANGELES      70
# ROSEMEAD         57
# SAN FRANCISCO    47
# SAN DIEGO        46
# TORRANCE         24
# dtype: int64

# %%
tp
# Out:
# LOS ANGELES      70
# ROSEMEAD         57
# SAN FRANCISCO    47
# SAN DIEGO        46
# TORRANCE         24
#                  ..
# CLEMENTS          1
# LUDLOW            1
# EL GRANADA        1
# SHASTA LAKE       1
# SUSANVILLE        1
# Length: 1026, dtype: int64

# %% [markdown]
# making all site city upper case

# %%
df['SiteCity'] = df['SiteCity'].str.upper()

# %%
lg = ['Local Government (Counties)',
 'Local Government ()',
 'Local Government (Cities)',
 'Local Government ']

localgov = df[df['Grouping'].isin(lg)]

# %%
lg_city_agg = localgov.groupby('SiteCity').sum().join(tp.rename('Total Programs')).reset_index()

# %%
lg_city_agg[lg_city_agg['SiteCity'] == 'TWIN PEAKS']
# Out:
# Empty DataFrame
# Columns: [SiteCity, TotalFirstYearGrosskWh, TotalFirstYearGrossTherm, TotalLifecycleGrosskWh, TotalLifecycleGrossTherm, Budget, Resource_Flag, OBF_Flag, Total Claims, Total Programs]
# Index: []

# %% [markdown]
# local gov total programs

# %%
lgprg = localgov.groupby(['SiteCity', 'PrgID'], dropna = False).size().index.tolist() 
#need to count the number of times a city shows up 

e,f = [list(c) for c in zip(*lgprg)]

lgccp = pd.Series(e) # made a series so can use value_counts

lgccp = lgccp.str.upper()

lgtp = lgccp.value_counts(dropna = False) #total programs per city

lgtp.head()
# Out:
# ROSEMEAD         26
# LOS ANGELES      26
# SAN FRANCISCO    10
# SAN DIEGO         8
# FRESNO            5
# dtype: int64

# %%
lg_city_agg = localgov.groupby('SiteCity').sum().join(lgtp.rename('Total Programs')).reset_index()

# %%
lg_city_agg.head()
# Out:
#    SiteCity  TotalFirstYearGrosskWh  TotalFirstYearGrossTherm  \
# 0    ACAMPO            48664.726740               -148.890330
# 1  ADELANTO           476437.532696                -90.111798
# 2     ALAMO            73049.392600                118.645240
# 3    ALBANY           158184.149000               -818.167334
# 4  ALHAMBRA            43261.898784                -64.344925
#
#    TotalLifecycleGrosskWh  TotalLifecycleGrossTherm         Budget  \
# 0            5.839767e+05              -1786.683960   17684.568509
# 1            1.946481e+06               -450.558990  262068.388232
# 2            6.850000e+05              -1279.097025   48785.542683
# 3            8.751087e+05              -4538.806680   63829.667146
# 4            2.404667e+05               -357.759876   96930.895202
#
#    Resource_Flag  OBF_Flag  Total Claims  Total Programs
# 0              6         0             6               1
# 1             37         0            37               2
# 2             15         2            15               1
# 3             40         0            40               2
# 4             14         0            14               1

# %%
lg_city_agg.rename(columns={'OBF_Flag':'OBF Claims', 'Resource_Flag':'Resource Claims'}, inplace=True)

# %%
lg_city_agg['% OBF'] = (lg_city_agg['OBF Claims']/lg_city_agg['Total Claims'])*100

lg_city_agg['% Resource'] = (lg_city_agg['Resource Claims']/lg_city_agg['Total Claims'])*100

# %%
lg_city_agg.head()
# Out:
#    SiteCity  TotalFirstYearGrosskWh  TotalFirstYearGrossTherm  \
# 0    ACAMPO            48664.726740               -148.890330
# 1  ADELANTO           476437.532696                -90.111798
# 2     ALAMO            73049.392600                118.645240
# 3    ALBANY           158184.149000               -818.167334
# 4  ALHAMBRA            43261.898784                -64.344925
#
#    TotalLifecycleGrosskWh  TotalLifecycleGrossTherm         Budget  \
# 0            5.839767e+05              -1786.683960   17684.568509
# 1            1.946481e+06               -450.558990  262068.388232
# 2            6.850000e+05              -1279.097025   48785.542683
# 3            8.751087e+05              -4538.806680   63829.667146
# 4            2.404667e+05               -357.759876   96930.895202
#
#    Resource Claims  OBF Claims  Total Claims  Total Programs      % OBF  \
# 0                6           0             6               1   0.000000
# 1               37           0            37               2   0.000000
# 2               15           2            15               1  13.333333
# 3               40           0            40               2   0.000000
# 4               14           0            14               1   0.000000
#
#    % Resource
# 0       100.0
# 1       100.0
# 2       100.0
# 3       100.0
# 4       100.0

# %%
lg_city_agg.to_csv('cpuc_city_agg.csv')

# %% [markdown]
# # the mystery of the discrepency in the number of claims

# %%
localgov['ClaimID'].value_counts()
# Out:
# SCE-2017-Q4-0362006    4
# SCE-2017-Q4-0379686    4
# PGE-2018-Q2-53857      4
# SCE-2017-Q4-0379775    4
# PGE-2018-Q2-53850      4
#                       ..
# PGE-2017-Q4-69739      1
# PGE-2017-Q4-80007      1
# PGE-2017-Q4-48056      1
# PGE-2017-Q1-10443      1
# PGE-2017-Q4-160100     1
# Name: ClaimID, Length: 193253, dtype: int64

# %%
localgov.columns
# Out:
# Index(['ClaimID', 'PrgID', 'SiteCity', 'TotalFirstYearGrosskWh',
#        'TotalFirstYearGrossTherm', 'TotalLifecycleGrosskWh',
#        'TotalLifecycleGrossTherm', 'Budget', 'Grouping', 'Resource_Flag',
#        'OBF_Flag', 'Total Claims'],
#       dtype='object')

# %%
nodups = localgov.drop_duplicates()

# %%
nodups['ClaimID'].value_counts()
# Out:
# PGE-2017-Q4-51525      1
# PGE-2018-Q4-93036      1
# PGE-2018-Q3-52890      1
# PGE-2018-Q1-48065      1
# PGE-2017-Q4-40246      1
#                       ..
# SCE-2017-Q4-0445900    1
# PGE-2018-Q1-38124      1
# PGE-2017-Q4-14694      1
# PGE-2018-Q4-75049      1
# PGE-2017-Q4-160100     1
# Name: ClaimID, Length: 193253, dtype: int64

# %% [markdown]
# # Aggregation Function

# %% [markdown]
# goal of this function is to have a reusable way to aggregate our data at a given level of speficity ie county and city.... esp because we will hopefully get data with a 'Total Expenditures' column, in which case we'll have to aggregate again...
#
# the function will have a few parameters:
# 1. df, the dataframe needed for aggregation
# 1. by=str, the column to do the groupby aggregation, in this case will most likely be city or county
# 1. lg=True , filters out local government programs, if False, doesn't do any filtering
# 1. column_list, a list of relevant columns to be in the final aggregated dataframe
# 1. more things if I think of them

# %%
cpuc.head()
# Out:
#    Unnamed: 0            ClaimID      PrgID Sector_x      SiteCity  \
# 0           0  PGE-2017-Q4-85848   PGE21015      Com    PLEASANTON
# 1           1  PGE-2017-Q4-94241  PGE211009      Res  WALNUT CREEK
# 2           2  PGE-2017-Q4-88304  PGE211009      Res    UNION CITY
# 3           3   PGE-2017-Q4-8624   PGE21012      Com  SAINT HELENA
# 4           4  PGE-2017-Q4-88820  PGE211009      Res       FREMONT
#
#   SiteZipCode       SiteID NAICSCode BldgHVAC BldgLoc  ... Custom_Flag  \
# 0       94588  PGE-1118107    541512    cPVVG    CZ12  ...       False
# 1       94596  PGE-1133955       NaN     rWtd    CZ12  ...        True
# 2       94587  PGE-1103730       NaN     rWtd      3A  ...        True
# 3       94574  PGE-1082391    713910     cWtd    CZ02  ...       False
# 4       94539  PGE-1120910       NaN     rWtd      3B  ...        True
#
#   Upstream_Flag_y Midstream_Flag Downstream_Flag DirectInstall Audit_Flag  \
# 0            True           True           False            No      False
# 1           False          False            True       Partial       True
# 2           False          False            True       Partial       True
# 3            True           True            True            No       True
# 4           False          False            True       Partial       True
#
#   Financing                          ParentProgram Exclude_From_Budget  \
# 0      None  Commercial Energy Efficiency Programs               False
# 1      None        Government Partnership Programs               False
# 2      None        Government Partnership Programs               False
# 3      None  Commercial Energy Efficiency Programs               False
# 4      None        Government Partnership Programs               False
#
#   Exclude_From_CE
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#
# [5 rows x 73 columns]

# %% [markdown]
# goal is to go from a dataframe like the one above with all necesary columns, and spit out a relevant aggregation

# %% [markdown]
# ### Making df Usable

# %%
# making df usable

df[by] = df[by].str.upper()
df['ClaimID'].drop_duplicates()

if df['ClaimID'].value_counts()[0] != 1:
    print("Sorry your dataset contains duplicates I don't know how to deal with")
    return

# %% [markdown]
# ### Local Government Filtering

# %%
#filtering for local government

if lg==True: 
    
    lg = ['Local Government (Counties)',
     'Local Government ()',
     'Local Government (Cities)',
     'Local Government ']

    localgov = df[df['Grouping'].isin(lg)]

# %% [markdown]
# ### Total Programs/Total Claims calculation

# %%
# creating a total programs column

prg = df.groupby([by, 'PrgID'], dropna = False).size().index.tolist() 
#need to count the number of times a city/county shows up 

e,f = [list(c) for c in zip(*prg)]

ccp = pd.Series(e) # made a series so can use value_counts

ccp = ccp.str.upper()

tp = ccp.value_counts(dropna = False) #total programs per city
# Out:
# ROSEMEAD         26
# LOS ANGELES      26
# SAN FRANCISCO    10
# SAN DIEGO         8
# FRESNO            5
# dtype: int64

# %%
# creating a total claims column

l = [1]*len(df)
total_claims = pd.Series(l).rename('Total Claims')
df = df.join(total_claims)

# %% [markdown]
# ### Actual Aggregation!

# %%
#aggregate!
df.groupby(by).sum()[column_list]

# %% [markdown]
# ---------
# --------
# ------

# %%
def aggregate_me(df, by, lg, column_list):
    
    # making df usable

    df[by] = df[by].str.upper()
    df.drop_duplicates()

    if df['ClaimID'].value_counts()[0] != 1:
        print("Sorry your dataset contains duplicates I don't know how to deal with")
        return

    #filtering for local government

    if lg==True: 

        lg = ['Local Government (Counties)',
         'Local Government ()',
         'Local Government (Cities)',
         'Local Government ']

        localgov = df[df['Grouping'].isin(lg)]


    # creating a total programs column

    prg = df.groupby([by, 'PrgID'], dropna = False).size().index.tolist() 
    #need to count the number of times a city/county shows up 

    e,f = [list(c) for c in zip(*prg)]

    ccp = pd.Series(e) # made a series so can use value_counts

    ccp = ccp.str.upper()

    tp = ccp.value_counts(dropna = False) #total programs per city


    # creating a total claims column

    l = [1]*len(df)
    total_claims = pd.Series(l).rename('Total Claims')
    df = df.join(total_claims)

    #aggregate!
    df.groupby(by).sum()[column_list]

# %%
aggregate_me(cpuc,'SiteCity',True, ['Budget','Total Claims'])
# Out:
# Sorry your dataset contains duplicates I don't know how to deal with

# %% [markdown]
# # small digression into dealing with duplicates

# %%
cpuc['ClaimID'].drop_duplicates()
# Out:
# 0                                   PGE-2017-Q4-85848
# 1                                   PGE-2017-Q4-94241
# 2                                   PGE-2017-Q4-88304
# 3                                    PGE-2017-Q4-8624
# 4                                   PGE-2017-Q4-88820
#                              ...
# 746368               SDGE-2019-4061-11015387-12663812
# 746369    SDGE-2019-4061-2019Q1ProgramCostPlaceholder
# 746370    SDGE-2019-4061-2019Q2ProgramCostPlaceholder
# 746371    SDGE-2019-4061-2019Q3ProgramCostPlaceholder
# 746372    SDGE-2019-4061-2019Q4PROGRAMCOSTPLACEHOLDER
# Name: ClaimID, Length: 599968, dtype: object

# %%
cpuc.drop_duplicates()
# Out:
#         Unnamed: 0                                      ClaimID      PrgID  \
# 0                0                            PGE-2017-Q4-85848   PGE21015
# 1                1                            PGE-2017-Q4-94241  PGE211009
# 2                2                            PGE-2017-Q4-88304  PGE211009
# 3                3                             PGE-2017-Q4-8624   PGE21012
# 4                4                            PGE-2017-Q4-88820  PGE211009
# ...            ...                                          ...        ...
# 746368      746368             SDGE-2019-4061-11015387-12663812   SDGE4061
# 746369      746369  SDGE-2019-4061-2019Q1ProgramCostPlaceholder   SDGE4061
# 746370      746370  SDGE-2019-4061-2019Q2ProgramCostPlaceholder   SDGE4061
# 746371      746371  SDGE-2019-4061-2019Q3ProgramCostPlaceholder   SDGE4061
# 746372      746372  SDGE-2019-4061-2019Q4PROGRAMCOSTPLACEHOLDER   SDGE4061
#
#           Sector_x      SiteCity SiteZipCode                   SiteID  \
# 0              Com    PLEASANTON       94588              PGE-1118107
# 1              Res  WALNUT CREEK       94596              PGE-1133955
# 2              Res    UNION CITY       94587              PGE-1103730
# 3              Com  SAINT HELENA       94574              PGE-1082391
# 4              Res       FREMONT       94539              PGE-1120910
# ...            ...           ...         ...                      ...
# 746368  Commercial     SAN DIEGO  92123-1417  SDGE-2019-4061-11015387
# 746369  Commercial     SAN DIEGO       92123    SDGE-2019-4061-2019Q1
# 746370  Commercial     SAN DIEGO       92123    SDGE-2019-4061-2019Q2
# 746371  Commercial     SAN DIEGO       92123    SDGE-2019-4061-2019Q3
# 746372  Commercial     SAN DIEGO       92123    SDGE-2019-4061-2019Q4
#
#        NAICSCode BldgHVAC BldgLoc  ... Custom_Flag Upstream_Flag_y  \
# 0         541512    cPVVG    CZ12  ...       False            True
# 1            NaN     rWtd    CZ12  ...        True           False
# 2            NaN     rWtd      3A  ...        True           False
# 3         713910     cWtd    CZ02  ...       False            True
# 4            NaN     rWtd      3B  ...        True           False
# ...          ...      ...     ...  ...         ...             ...
# 746368    522110      Any    CZ07  ...       False           False
# 746369       NaN      Any    CZ07  ...       False           False
# 746370       NaN      Any    CZ07  ...       False           False
# 746371       NaN      Any    CZ07  ...       False           False
# 746372       NaN      Any    CZ07  ...       False           False
#
#        Midstream_Flag Downstream_Flag DirectInstall Audit_Flag Financing  \
# 0                True           False            No      False      None
# 1               False            True       Partial       True      None
# 2               False            True       Partial       True      None
# 3                True            True            No       True      None
# 4               False            True       Partial       True      None
# ...               ...             ...           ...        ...       ...
# 746368          False           False            No       True      None
# 746369          False           False            No       True      None
# 746370          False           False            No       True      None
# 746371          False           False            No       True      None
# 746372          False           False            No       True      None
#
#                                 ParentProgram Exclude_From_Budget  \
# 0       Commercial Energy Efficiency Programs               False
# 1             Government Partnership Programs               False
# 2             Government Partnership Programs               False
# 3       Commercial Energy Efficiency Programs               False
# 4             Government Partnership Programs               False
# ...                                       ...                 ...
# 746368                                    NaN               False
# 746369                                    NaN               False
# 746370                                    NaN               False
# 746371                                    NaN               False
# 746372                                    NaN               False
#
#        Exclude_From_CE
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ...                ...
# 746368           False
# 746369           False
# 746370           False
# 746371           False
# 746372           False
#
# [746373 rows x 73 columns]

# %%
cpuc['ClaimID'].value_counts()
# Out:
# SCE-2017-Q4-0362024                4
# SCE-2017-Q4-0362069                4
# SCE-2017-Q4-0379570                4
# SCE-2017-Q4-0379582                4
# SCE-2017-Q4-0368786                4
#                                   ..
# SDGE-2018-3224-10896802-9048370    1
# PGE-2017-Q2-48746                  1
# PGE-2018-Q1-65414                  1
# SCG-2019-3711-12184368-3335044     1
# SDGE-2018-3224-10896803-9048466    1
# Name: ClaimID, Length: 599968, dtype: int64

# %%
cpuc.drop(columns='Unnamed: 0', inplace=True)

# %%
cpuc.drop_duplicates()['ClaimID'].value_counts().head(10)
# Out:
# SCE-2017-Q4-0201694                 2
# SCE-2018-Q4-0101513                 2
# SCE-2017-Q4-0201431                 2
# SCE-2018-Q4-0114147                 2
# SCE-2018-Q2-0069119                 2
# SCE-2019-Q2-0042829                 2
# SCE-2017-Q2-0149031                 1
# SCE-2017-Q4-0268537                 1
# SDGE-2019-3224-11022181-12683213    1
# PGE-2019-Q1-5802                    1
# Name: ClaimID, dtype: int64

# %%
cpuc.columns
# Out:
# Index(['ClaimID', 'PrgID', 'Sector_x', 'SiteCity', 'SiteZipCode', 'SiteID',
#        'NAICSCode', 'BldgHVAC', 'BldgLoc', 'BldgType', 'BldgVint',
#        'E3ClimateZone', 'E3GasSavProfile', 'E3GasSector',
#        'E3MeaElecEndUseShape', 'E3TargetSector', 'ImplementationID',
#        'InstallationDate', 'NAICSBldgType', 'NumUnits', 'OBF_Flag',
#        'PrgElement', 'RateScheduleElec', 'RateScheduleGas', 'REN_Flag',
#        'Residential_Flag', 'SchoolIdentifier', 'TotalFirstYearGrosskW',
#        'TotalFirstYearGrosskWh', 'TotalFirstYearGrossTherm',
#        'TotalGrossIncentive', 'TotalGrossMeasureCost',
#        'TotalGrossMeasureCost_ER', 'TotalLifecycleGrosskW',
#        'TotalLifecycleGrosskWh', 'TotalLifecycleGrossTherm', 'Upstream_Flag_x',
#        'WaterOnly_Flag', 'PrgYear', 'Claim ID', 'Program ID',
#        'First Year Gross kWh', 'First Year Gross Therm', 'Budget', 'PA',
#        'ProgramName', 'Grouping', 'County', 'Selected', 'PrimarySector',
#        'Sector_y', 'BP Sector', 'ProgramImplementer', 'ProgramCategory',
#        'StatewideProgram', 'ImplementationContractor', 'ProgramManager',
#        'StartYear', 'EndYear', 'Resource_Flag', 'NonResource_Flag',
#        'Deemed_Flag', 'Custom_Flag', 'Upstream_Flag_y', 'Midstream_Flag',
#        'Downstream_Flag', 'DirectInstall', 'Audit_Flag', 'Financing',
#        'ParentProgram', 'Exclude_From_Budget', 'Exclude_From_CE'],
#       dtype='object')

# %%
cpuc[cpuc['ClaimID']=='SCE-2017-Q4-0201694']
# Out:
#                     ClaimID           PrgID Sector_x SiteCity SiteZipCode  \
# 327677  SCE-2017-Q4-0201694  SCE-13-SW-002D      Com   CARSON       90746
# 327681  SCE-2017-Q4-0201694  SCE-13-SW-002D      Com   CARSON       90746
#
#               SiteID NAICSCode BldgHVAC BldgLoc BldgType  ... Custom_Flag  \
# 327677  SCE_00984706    722211      Any    CZ08      RFF  ...       False
# 327681  SCE_00984706    722211      Any    CZ08      RFF  ...       False
#
#        Upstream_Flag_y Midstream_Flag Downstream_Flag DirectInstall  \
# 327677           False          False           False           Yes
# 327681           False          False           False           Yes
#
#        Audit_Flag Financing                                   ParentProgram  \
# 327677      False       OBF  Statewide Commercial Energy Efficiency Program
# 327681      False       OBF  Statewide Commercial Energy Efficiency Program
#
#        Exclude_From_Budget  Exclude_From_CE
# 327677               False            False
# 327681               False            False
#
# [2 rows x 72 columns]

# %%
a = cpuc.iloc[327677, :].to_frame().transpose()
b = cpuc.iloc[327681, :].to_frame().transpose()

# %%
a[~a.isin(b)]
# Out:
#                     ClaimID           PrgID Sector_x SiteCity SiteZipCode  \
# 327677  SCE-2017-Q4-0201694  SCE-13-SW-002D      Com   CARSON       90746
#
#               SiteID NAICSCode BldgHVAC BldgLoc BldgType  ... Custom_Flag  \
# 327677  SCE_00984706    722211      Any    CZ08      RFF  ...       False
#
#        Upstream_Flag_y Midstream_Flag Downstream_Flag DirectInstall  \
# 327677           False          False           False           Yes
#
#        Audit_Flag Financing                                   ParentProgram  \
# 327677      False       OBF  Statewide Commercial Energy Efficiency Program
#
#        Exclude_From_Budget Exclude_From_CE
# 327677               False           False
#
# [1 rows x 72 columns]

# %%
same = a.merge(b, left_on='ClaimID', right_on='ClaimID',how='inner')

# %%
same.columns
# Out:
# Index(['ClaimID', 'PrgID_x', 'Sector_x_x', 'SiteCity_x', 'SiteZipCode_x',
#        'SiteID_x', 'NAICSCode_x', 'BldgHVAC_x', 'BldgLoc_x', 'BldgType_x',
#        ...
#        'Custom_Flag_y', 'Upstream_Flag_y_y', 'Midstream_Flag_y',
#        'Downstream_Flag_y', 'DirectInstall_y', 'Audit_Flag_y', 'Financing_y',
#        'ParentProgram_y', 'Exclude_From_Budget_y', 'Exclude_From_CE_y'],
#       dtype='object', length=143)

# %%
dif = same = a.merge(b, left_on='ClaimID', right_on='ClaimID',how='outer')

# %%
dif.columns
# Out:
# Index(['ClaimID', 'PrgID_x', 'Sector_x_x', 'SiteCity_x', 'SiteZipCode_x',
#        'SiteID_x', 'NAICSCode_x', 'BldgHVAC_x', 'BldgLoc_x', 'BldgType_x',
#        ...
#        'Custom_Flag_y', 'Upstream_Flag_y_y', 'Midstream_Flag_y',
#        'Downstream_Flag_y', 'DirectInstall_y', 'Audit_Flag_y', 'Financing_y',
#        'ParentProgram_y', 'Exclude_From_Budget_y', 'Exclude_From_CE_y'],
#       dtype='object', length=143)

# %% [markdown]
# ## get rid of duplications function whee
# going to have to manually look into value_counts of 'claimid' in order to determine the parameter n, the number of distinct claims that have duplicates.

# %%
#creating df of number of times a claim repeats

repeats = df['ClaimID'].value_counts().to_frame().reset_index()

# %%
repeats.head()
# Out:
#                  index  ClaimID
# 0  SCE-2017-Q4-0362024        4
# 1  SCE-2017-Q4-0362069        4
# 2  SCE-2017-Q4-0379570        4
# 3  SCE-2017-Q4-0379582        4
# 4  SCE-2017-Q4-0368786        4

# %%
#getting list of duplicate claims

n=4
dupes=[]
for i in range(0,n+1):
    if repeats.loc[i, 'ClaimID']>1:
        dupes.append(repeats.loc[i, 'index'])
print(dupes)
# Out:
# ['SCE-2017-Q4-0362024', 'SCE-2017-Q4-0362069', 'SCE-2017-Q4-0379570', 'SCE-2017-Q4-0379582', 'SCE-2017-Q4-0368786']

# %%
df[df['ClaimID'].isin(dupes)]
# Out:
#                     ClaimID           PrgID   SiteCity  \
# 366661  SCE-2017-Q4-0362069  SCE-13-SW-002D     CARSON
# 366662  SCE-2017-Q4-0362069  SCE-13-SW-002D     CARSON
# 366663  SCE-2017-Q4-0362069  SCE-13-SW-002D     CARSON
# 366664  SCE-2017-Q4-0362069  SCE-13-SW-002D     CARSON
# 378070  SCE-2017-Q4-0362024  SCE-13-SW-002D  PARAMOUNT
# 378071  SCE-2017-Q4-0362024  SCE-13-SW-002D  PARAMOUNT
# 378072  SCE-2017-Q4-0362024  SCE-13-SW-002D  PARAMOUNT
# 378073  SCE-2017-Q4-0362024  SCE-13-SW-002D  PARAMOUNT
# 494486  SCE-2017-Q4-0379570  SCE-13-SW-002D     COVINA
# 494487  SCE-2017-Q4-0379570  SCE-13-SW-002D     COVINA
# 494488  SCE-2017-Q4-0379570  SCE-13-SW-002D     COVINA
# 494489  SCE-2017-Q4-0379570  SCE-13-SW-002D     COVINA
# 500231  SCE-2017-Q4-0368786  SCE-13-SW-002D     TULARE
# 500233  SCE-2017-Q4-0368786  SCE-13-SW-002D     TULARE
# 500235  SCE-2017-Q4-0368786  SCE-13-SW-002D     TULARE
# 500237  SCE-2017-Q4-0368786  SCE-13-SW-002D     TULARE
# 500328  SCE-2017-Q4-0379582  SCE-13-SW-002D     CARSON
# 500329  SCE-2017-Q4-0379582  SCE-13-SW-002D     CARSON
# 500330  SCE-2017-Q4-0379582  SCE-13-SW-002D     CARSON
# 500331  SCE-2017-Q4-0379582  SCE-13-SW-002D     CARSON
#
#         TotalFirstYearGrosskWh  TotalFirstYearGrossTherm  \
# 366661              402.325000                  -1.85725
# 366662              402.325000                  -1.85725
# 366663              402.325000                  -1.85725
# 366664              402.325000                  -1.85725
# 378070              159.600000                  -0.18677
# 378071              159.600000                  -0.18677
# 378072              159.600000                  -0.18677
# 378073              159.600000                  -0.18677
# 494486               20.710000                  -0.03154
# 494487               20.710000                  -0.03154
# 494488               20.710000                  -0.03154
# 494489               20.710000                  -0.03154
# 500231              258.400000                  -0.89300
# 500233              258.400000                  -0.89300
# 500235              258.400000                  -0.89300
# 500237              258.400000                  -0.89300
# 500328               30.457152                  -0.02148
# 500329               30.457152                  -0.02148
# 500330               30.457152                  -0.02148
# 500331               30.457152                  -0.02148
#
#         TotalLifecycleGrosskWh  TotalLifecycleGrossTherm      Budget Grouping  \
# 366661             6034.875000                -27.858750  255.992514      NaN
# 366662             6034.875000                -27.858750  255.992514      NaN
# 366663             6034.875000                -27.858750  255.992514      NaN
# 366664             6034.875000                -27.858750  255.992514      NaN
# 378070             1424.430000                 -1.669188   82.900487      NaN
# 378071             1424.430000                 -1.669188   82.900487      NaN
# 378072             1424.430000                 -1.669188   82.900487      NaN
# 378073             1424.430000                 -1.669188   82.900487      NaN
# 494486              310.650000                 -0.473100   43.521952      NaN
# 494487              310.650000                 -0.473100   43.521952      NaN
# 494488              310.650000                 -0.473100   43.521952      NaN
# 494489              310.650000                 -0.473100   43.521952      NaN
# 500231             3876.000000                -13.395000  278.243695      NaN
# 500233             3876.000000                -13.395000  278.243695      NaN
# 500235             3876.000000                -13.395000  278.243695      NaN
# 500237             3876.000000                -13.395000  278.243695      NaN
# 500328              365.485824                 -0.257764   46.149503      NaN
# 500329              365.485824                 -0.257764   46.149503      NaN
# 500330              365.485824                 -0.257764   46.149503      NaN
# 500331              365.485824                 -0.257764   46.149503      NaN
#
#         Resource_Flag  OBF_Flag  Total Claims
# 366661           True     False             1
# 366662           True     False             1
# 366663           True     False             1
# 366664           True     False             1
# 378070           True     False             1
# 378071           True     False             1
# 378072           True     False             1
# 378073           True     False             1
# 494486           True     False             1
# 494487           True     False             1
# 494488           True     False             1
# 494489           True     False             1
# 500231           True     False             1
# 500233           True     False             1
# 500235           True     False             1
# 500237           True     False             1
# 500328           True     False             1
# 500329           True     False             1
# 500330           True     False             1
# 500331           True     False             1

# %% [markdown]
# need to somehow store the first index value of each claim ID
#
# could make list of indicies for each claimid and then take the lowest one, making sure there is still one instance of the claim id in the dataset

# %%
#getting one index value per duplicate claim

goodi=[]
for e in dupes:
    goodi.append(min(df[df['ClaimID'].isin([e])].index.to_list()))
print(goodi)
# Out:
# [378070, 366661, 494486, 500328, 500231]

# %%
# full list of duplicate claim indicies

alli=[]
for e in dupes:
    alli = alli + df[df['ClaimID'].isin([e])].index.to_list()
print(badi)
# Out:
# [378070, 378071, 378072, 378073, 366661, 366662, 366663, 366664, 494486, 494487, 494488, 494489, 500328, 500329, 500330, 500331, 500231, 500233, 500235, 500237]

# %%
type(alli)
# Out:
# list

# %%
# take goodi from alli
badi = [i for i in alli if i not in goodi]

# %%
len(badi)
# Out:
# 15

# %%
len(goodi)
# Out:
# 5

# %%
len(alli)
# Out:
# 20

# %%
#drop duplicate indicies
df.drop(index=badi)
# Out:
#                                             ClaimID      PrgID      SiteCity  \
# 0                                 PGE-2017-Q4-85848   PGE21015    PLEASANTON
# 1                                 PGE-2017-Q4-94241  PGE211009  WALNUT CREEK
# 2                                 PGE-2017-Q4-88304  PGE211009    UNION CITY
# 3                                  PGE-2017-Q4-8624   PGE21012  SAINT HELENA
# 4                                 PGE-2017-Q4-88820  PGE211009       FREMONT
# ...                                             ...        ...           ...
# 746368             SDGE-2019-4061-11015387-12663812   SDGE4061     SAN DIEGO
# 746369  SDGE-2019-4061-2019Q1ProgramCostPlaceholder   SDGE4061     SAN DIEGO
# 746370  SDGE-2019-4061-2019Q2ProgramCostPlaceholder   SDGE4061     SAN DIEGO
# 746371  SDGE-2019-4061-2019Q3ProgramCostPlaceholder   SDGE4061     SAN DIEGO
# 746372  SDGE-2019-4061-2019Q4PROGRAMCOSTPLACEHOLDER   SDGE4061     SAN DIEGO
#
#         TotalFirstYearGrosskWh  TotalFirstYearGrossTherm  \
# 0                 17006.650170                  1790.515
# 1                    35.040000                    -0.832
# 2                    13.140000                    -0.312
# 3                     0.000000                   643.678
# 4                    35.040000                    -0.832
# ...                        ...                       ...
# 746368             2533.022933                     0.000
# 746369                0.000000                     0.000
# 746370                0.000000                     0.000
# 746371                0.000000                     0.000
# 746372                0.000000                     0.000
#
#         TotalLifecycleGrosskWh  TotalLifecycleGrossTherm       Budget  \
# 0                 56121.945550                 5908.6995  5541.932761
# 1                   560.640000                  -13.3120   106.846221
# 2                   210.240000                   -4.9920    39.779768
# 3                     0.000000                12873.5600  1354.671628
# 4                   560.640000                  -13.3120   106.118823
# ...                        ...                       ...          ...
# 746368             5066.045866                    0.0000   748.712453
# 746369                0.000000                    0.0000     0.000000
# 746370                0.000000                    0.0000     0.000000
# 746371                0.000000                    0.0000     0.000000
# 746372                0.000000                    0.0000     0.000000
#
#                            Grouping  Resource_Flag  OBF_Flag  Total Claims
# 0                               NaN           True     False             1
# 1       Local Government (Counties)           True     False             1
# 2       Local Government (Counties)           True     False             1
# 3                               NaN           True     False             1
# 4       Local Government (Counties)           True     False             1
# ...                             ...            ...       ...           ...
# 746368                          NaN           True     False             1
# 746369                          NaN           True     False             1
# 746370                          NaN           True     False             1
# 746371                          NaN           True     False             1
# 746372                          NaN           True     False             1
#
# [746358 rows x 12 columns]

# %%
df.drop(labels=badi, axis=0)['ClaimID'].value_counts()
# Out:
# SCE-2017-Q4-0365983                4
# SCE-2017-Q4-0362042                4
# SCE-2017-Q4-0365958                4
# SCE-2017-Q4-0379696                4
# SCE-2017-Q4-0361149                4
#                                   ..
# PGE-2017-Q2-48746                  1
# PGE-2018-Q1-65414                  1
# SCG-2019-3711-12184368-3335044     1
# PGE-2018-Q4-87850                  1
# SDGE-2018-3224-10896803-9048466    1
# Name: ClaimID, Length: 599968, dtype: int64

# %%
def no_dupes(df):
    
    #creating df of number of times a claim repeats

    repeats = df['ClaimID'].value_counts().to_frame().reset_index()

    #getting list of duplicate claims
    
    all_dupes = repeats[repeats['ClaimID']>1]
    n = len(all_dupes)
    dupes=[]
    for i in range(0,n):
        if repeats.loc[i, 'ClaimID']>1:
            dupes.append(repeats.loc[i, 'index'])
    print(dupes)

    #getting one index value per duplicate claim

    goodi=[]
    for e in dupes:
        goodi.append(min(df[df['ClaimID'].isin([e])].index.to_list()))
    print(goodi)

    # full list of duplicate claim indicies

    alli=[]
    for e in dupes:
        alli = alli + df[df['ClaimID'].isin([e])].index.to_list()
    print(badi)


    # take goodi from alli
    badi = [i for i in alli if i not in goodi]

    #drop duplicate indicies
    df.drop(index=badi, inplace=True)

# %%
copy = cpuc.copy()

# %%
copy['ClaimID'].value_counts().head(1000)
# Out:
# SCE-2017-Q4-0362024    4
# SCE-2017-Q4-0362069    4
# SCE-2017-Q4-0379570    4
# SCE-2017-Q4-0379582    4
# SCE-2017-Q4-0368786    4
#                       ..
# PGE-2017-Q1-42461      3
# SCE-2018-Q3-0000425    3
# PGE-2018-Q2-31951      3
# SCE-2017-Q1-0068701    3
# SCE-2018-Q2-0071312    3
# Name: ClaimID, Length: 1000, dtype: int64

# %%
all_dupes = repeats[repeats['ClaimID']>1]
n = len(all_dupes)
# Out:
# 138010

# %%
no_dupes(copy)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
