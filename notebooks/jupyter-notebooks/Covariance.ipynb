# %%
import pandas as pd
import numpy as np

# %%
counties = pd.read_csv('data/better_cpuc_compiled.csv')

counties.drop(columns='Unnamed: 0', inplace = True)

counties.rename(columns={'Tax Revenue (2016-2018)':'Tax Revenue'}, inplace=True)

df = counties.copy()

# %%
df.drop(columns='County', inplace=True)

# %%
array=df.to_numpy

# %%
df.cov()
# Out:
#                             Population   Mean Income  CES Score Median  \
# Population                2.159502e+12  2.769706e+08      3.395563e+06
# Mean Income               2.769706e+08  7.061489e+07     -1.727793e+03
# CES Score Median          3.395563e+06 -1.727793e+03      1.036509e+02
# TotalFirstYearGrosskWh    1.532625e+12  3.324769e+09      4.218608e+06
# TotalFirstYearGrossTherm  2.055267e+09 -1.008396e+07      2.511590e+03
# Budget                    2.718075e+12  7.033300e+09      5.256272e+05
# Total Claims              2.767494e+08  9.764188e+06     -3.313857e+03
# Total Programs            2.115061e+06  1.432640e+03      3.455609e+00
# IRR                      -9.497879e+04 -8.461399e+01     -1.463359e-01
# Tax Revenue               4.401736e+15  1.354729e+12      6.510483e+09
#
#                           TotalFirstYearGrosskWh  TotalFirstYearGrossTherm  \
# Population                          1.532625e+12              2.055267e+09
# ...
